# %% [markdown]
# <a href="https://colab.research.google.com/github/HuynhDuyNhan/AI/blob/main/Robot_2_b%E1%BA%ADc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv ('robot2bac.csv')
data.head()
# Out:
#    tt1  tt2         Px        Py
# 0  0.0  0.0  90.000000  0.000000
# 1  0.0  2.0  89.975633  1.395980
# 2  0.0  4.0  89.902562  2.790259
# 3  0.0  6.0  89.780876  4.181139
# 4  0.0  8.0  89.610723  5.566924

# %%
#x=data.iloc[:,[2,3]]
#y=data.iloc[:,[0,1]]
x_data=data.drop(['tt1','tt2'],axis=1)
y_data=data[['tt1','tt2']]

# %%
x_data
# Out:
#              Px        Py
# 0     90.000000  0.000000
# 1     89.975633  1.395980
# 2     89.902562  2.790259
# 3     89.780876  4.181139
# 4     89.610723  5.566924
# ...         ...       ...
# 8095 -10.843637 -6.571493
# 8096 -10.577231 -5.200952
# 8097 -10.358819 -3.821949
# 8098 -10.188666 -2.436164
# 8099 -10.066979 -1.045284
#
# [8100 rows x 2 columns]

# %%
y_data
# Out:
#         tt1    tt2
# 0       0.0    0.0
# 1       0.0    2.0
# 2       0.0    4.0
# 3       0.0    6.0
# 4       0.0    8.0
# ...     ...    ...
# 8095  178.0  170.0
# 8096  178.0  172.0
# 8097  178.0  174.0
# 8098  178.0  176.0
# 8099  178.0  178.0
#
# [8100 rows x 2 columns]

# %%
#from sklearn.preprocessing import scale
#from sklearn.preprocessing import StandardScaler
#cal_names = list(x.columns)
#scaler = StandardScaler()
#x_df = scaler.fit_transform(x)
#x_df = pd.DataFrame(x_df,columns=cal_names)
#x_df

# %%
from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test = train_test_split(x_df,y,test_size=0.25,random_state=7)
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.2,random_state=7)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.callbacks import EarlyStopping

#model=Sequential() 
#model.add(Dense(512,activation='relu',input_shape=(2,))) 
#model.add(Dropout(0.1))
#model.add(Dense(512,activation='relu')) 
#model.add(Dropout(0.1))
#model.add(Dense(512,activation='relu')) 
#model.add(Dropout(0.1))
#model.add(Dense(2,activation='linear'))
#model.summary()

model=Sequential()
model.add(Dense(128, activation='relu', input_shape = (2,))) 
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2,  activation='linear'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 128)               384
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 32)                2080
#
#  dense_15 (Dense)            (None, 16)                528
#
#  dense_16 (Dense)            (None, 8)                 136
#
#  dense_17 (Dense)            (None, 2)                 18
#
# ...
# Total params: 11,402
# Trainable params: 11,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
#x_train_scale=scale(x_train)
#scaler=StandardScaler().fit(x_train)
#x_test_scale=scaler.transform(x_test)

# %%
model.compile(loss='mse',metrics=['mean_absolute_error'])
history= model.fit(x_train, y_train, batch_size=100, epochs=500, verbose=1, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/500
# 52/52 [==============================] - 1s 6ms/step - loss: 6698.0083 - mean_absolute_error: 64.8361 - val_loss: 4009.0605 - val_mean_absolute_error: 45.5042
# Epoch 2/500
# 52/52 [==============================] - 0s 3ms/step - loss: 3873.5620 - mean_absolute_error: 44.2438 - val_loss: 3773.4741 - val_mean_absolute_error: 43.6337
# Epoch 3/500
# 52/52 [==============================] - 0s 3ms/step - loss: 3744.9602 - mean_absolute_error: 43.3211 - val_loss: 3745.8936 - val_mean_absolute_error: 44.1235
# Epoch 4/500
# 52/52 [==============================] - 0s 3ms/step - loss: 3676.1855 - mean_absolute_error: 42.9056 - val_loss: 3655.9819 - val_mean_absolute_error: 41.2941
# Epoch 5/500
# 52/52 [==============================] - 0s 3ms/step - loss: 3593.6880 - mean_absolute_error: 42.3989 - val_loss: 3713.8552 - val_mean_absolute_error: 44.3699
# Epoch 6/500
# ...

# %%
score=model.evaluate(x_test,y_test,verbose=0)
print('Test loss',score[0])
print('Test accuracy',score[1])
# Out:
# Test loss 11.696135520935059
# Test accuracy 2.0873875617980957

# %%
import numpy as np
predictions=model.predict(x_test)
y_test=np.array(y_test)
print("gia tri du doan:", predictions[3])
print("gia tri thuc:",y_test[3])
# Out:
# gia tri du doan: [ 35.615234 161.34753 ]
# gia tri thuc: [ 36. 162.]
